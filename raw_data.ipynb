# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
input_data = "cve_data.csv"

# %%
data = pd.read_csv(input_data)

# %%
data.head()
# Out:
#           cve_id  cwe_id                                             cpe_id  \
# 0  CVE-2009-4539  CWE-79  cpe:2.3:a:sqlitemanager:sqlitemanager:1.2.0:*:...
# 1  CVE-2009-4540  CWE-89  cpe:2.3:a:bpowerhouse:mini_cms:1.0.1:*:*:*:*:*...
# 2  CVE-2009-4541  CWE-94  cpe:2.3:a:isolsoft:support_center:2.5:*:*:*:*:...
# 3  CVE-2009-4542  CWE-79  cpe:2.3:a:isolsoft:support_center:2.5:*:*:*:*:...
# 4  CVE-2009-4543  CWE-94  cpe:2.3:a:cromosoft:facil_helpdesk:2.3:*:*:*:*...
#
#                                          description    status  \
# 0  Cross-site scripting (XSS) vulnerability in ma...  Modified
# 1  SQL injection vulnerability in page.php in Min...  Modified
# 2  Multiple PHP remote file inclusion vulnerabili...  Modified
# 3  Cross-site scripting (XSS) vulnerability in ne...  Modified
# 4  PHP remote file inclusion vulnerability in ind...  Modified
#
#                 created_at              modified_at
# 0  2010-01-04T17:30:00.390  2018-10-10T19:49:18.103
# 1  2010-01-04T17:30:00.420  2017-09-19T01:29:58.720
# 2  2010-01-04T17:30:00.437  2017-09-19T01:29:58.780
# 3  2010-01-04T17:30:00.467  2017-09-19T01:29:58.827
# 4  2010-01-04T17:30:00.483  2017-09-19T01:29:58.890

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168800 entries, 0 to 168799
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   cve_id       168800 non-null  object
#  1   cwe_id       156615 non-null  object
#  2   cpe_id       156376 non-null  object
#  3   description  168800 non-null  object
#  4   status       168800 non-null  object
#  5   created_at   168800 non-null  object
#  6   modified_at  168800 non-null  object
# dtypes: object(7)
# memory usage: 9.0+ MB

# %%
cpe_parts = data['cpe_id'].str.split(":", expand=True)

# %%
data['vendor'] = cpe_parts[3]
data['product'] = cpe_parts[4]

# %%
null_counts = data.isnull().sum()
null_counts
# Out:
# cve_id             0
# cwe_id         12185
# cpe_id         12424
# description        0
# status             0
# created_at         0
# modified_at        0
# vendor         12424
# product        12424
# dtype: int64

# %%
data.dropna(subset='cpe_id', inplace = True)

# %%
null_counts = data.isnull().sum()
null_counts
# Out:
# cve_id         0
# cwe_id         1
# cpe_id         0
# description    0
# status         0
# created_at     0
# modified_at    0
# vendor         0
# product        0
# dtype: int64

# %%
  data.dropna(subset=['cwe_id'], inplace=True)

# %%
data.drop('cpe_id', axis=1, inplace=True)

# %%
data.describe()
# Out:
#                cve_id          cwe_id  \
# count          156375          156375
# unique         156375             357
# top     CVE-2023-1148  NVD-CWE-noinfo
# freq                1           20897
#
#                                               description    status  \
# count                                              156375    156375
# unique                                             150195         3
# top     A remote code execution vulnerability was iden...  Analyzed
# freq                                                   83    118509
#
#                      created_at              modified_at  vendor  product
# count                    156375                   156375  156375   156375
# unique                   156314                   133418   19470    34067
# top     2014-04-23T11:52:59.167  2019-10-03T00:03:26.223  google  android
# freq                          3                     5591    8929     5529

# %%
dubl = data.duplicated().sum()
dubl
# Out:
# np.int64(0)

# %%
data['vendor'] = data['vendor'].str.strip().str.lower()
data['product'] = data['product'].str.strip().str.lower()

# %%
data['created_at'] = pd.to_datetime(data['created_at'], errors='coerce')
data['modified_at'] = pd.to_datetime(data['modified_at'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 156375 entries, 0 to 168642
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   cve_id       156375 non-null  object
#  1   cwe_id       156375 non-null  object
#  2   description  156375 non-null  object
#  3   status       156375 non-null  object
#  4   created_at   156375 non-null  datetime64[ns]
#  5   modified_at  156375 non-null  datetime64[ns]
#  6   vendor       156375 non-null  object
#  7   product      156375 non-null  object
# dtypes: datetime64[ns](2), object(6)
# memory usage: 10.7+ MB

# %%
DB_URL = 'postgresql://postgres:*******************************************

# %%
engine = create_engine(DB_URL)

# %%
data.to_sql('pa_cve_data_new', engine, if_exists='append', index=False)
# Out:
# 375
